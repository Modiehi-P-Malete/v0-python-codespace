# %%
def exclaim(s):
    capitalized = s.upper()
    return capitalized + "!!"

result = exclaim("potato")
print(result)
print(len(result))
print(result[0])
print(result[-1])
# Out:
# POTATO!!
# 8
# P
# !
